# %%
import pandas as pd

source = pd.read_csv("v4_buisInvest_2200.csv")
source.columns.values
# Out:
# array(['v4_0', 'calendar-years', 'Time', 'uk-only', 'Geography',
#        'business-investment-activity', 'activity',
#        'business-investment-instrument-asset', 'instrument-asset',
#        'business-investment-prices', 'prices'], dtype=object)

# %%
df = pd.DataFrame()

df["Codelist"] = source["activity"] # just to populate right number of row
df["Codelist"] = 'business-investment-activity'

df["Code"] = source["business-investment-activity"]
df["Label"] = source["activity"]

df["ParentCode"] = ""

df = df.drop_duplicates()

pd.set_option('display.max_rows', 100) # lets see all the codes
print(len(df))
df
# Out:
# 87
#                           Codelist    Code  \
# 0     business-investment-activity       L
# 44    business-investment-activity      _T
# 110   business-investment-activity       A
# 176   business-investment-activity     A01
# 242   business-investment-activity     A02
# 308   business-investment-activity     A03
# 374   business-investment-activity       B
# 440   business-investment-activity     BTE
# 506   business-investment-activity       C
# 572   business-investment-activity  C10T12
# 638   business-investment-activity  C13T15
# 704   business-investment-activity     C16
# 770   business-investment-activity  C16T18
# 836   business-investment-activity     C17
# 902   business-investment-activity     C18
# 968   business-investment-activity     C19
# 1034  business-investment-activity     C20
# 1100  business-investment-activity     C21
# 1166  business-investment-activity     C22
# 1232  business-investment-activity  C22_23
# 1298  business-investment-activity     C23
# 1364  business-investment-activity     C24
# 1430  business-investment-activity  C24_25
# 1496  business-investment-activity     C25
# 1562  business-investment-activity     C26
# 1628  business-investment-activity     C27
# 1694  business-investment-activity     C28
# 1760  business-investment-activity     C29
# 1826  business-investment-activity  C29_30
# 1892  business-investment-activity     C30
# 1958  business-investment-activity  C31T33
# 2024  business-investment-activity  C31_32
# 2090  business-investment-activity     C33
# 2156  business-investment-activity       D
# 2222  business-investment-activity       E
# 2288  business-investment-activity     E36
# 2354  business-investment-activity  E37T39
# 2420  business-investment-activity       F
# 2486  business-investment-activity       G
# 2552  business-investment-activity     G45
# 2618  business-investment-activity     G46
# 2684  business-investment-activity     G47
# 2750  business-investment-activity       H
# 2816  business-investment-activity     H49
# 2882  business-investment-activity     H50
# 2948  business-investment-activity     H51
# 3014  business-investment-activity     H52
# 3080  business-investment-activity     H53
# 3146  business-investment-activity       I
# 3212  business-investment-activity       J
# 3278  business-investment-activity     J58
# 3344  business-investment-activity  J58T60
# 3410  business-investment-activity  J59_60
# 3476  business-investment-activity     J61
# 3542  business-investment-activity  J62_63
# 3608  business-investment-activity       K
# 3674  business-investment-activity     K64
# 3740  business-investment-activity     K65
# 3806  business-investment-activity     K66
# 3938  business-investment-activity       M
# 4004  business-investment-activity  M69T71
# 4070  business-investment-activity  M69_70
# 4136  business-investment-activity     M71
# 4202  business-investment-activity     M72
# 4268  business-investment-activity     M73
# 4334  business-investment-activity  M73T75
# 4400  business-investment-activity  M74_75
# 4466  business-investment-activity     M_N
# 4532  business-investment-activity       N
# 3938  Professional, scientific and technical activities
# 4004  Legal and accounting activities; activities of...
# 4070  Legal and accounting activities; activities of...
# 4136  Architectural and engineering activities; tech...
# 4202                Scientific research and development
# 4268                    Advertising and market research
# 4334  Advertising and market research; other profess...
# 4400  Other professional, scientific and technical a...
# 4466  Professional, scientific and technical activit...
# 4532      Administrative and support service activities
# 4598                      Rental and leasing activities
# 4664                              Employment activities
# 4730  Travel agency, tour operator reservation servi...
# 4796  Security and investigation, service and landsc...
# 4862  Public administration and defence; compulsory ...
# 4928  Public administration, defence, education, hum...
# 4994                                          Education
# 5060            Human health and social work activities
# 5126                            Human health activities
# 5192  Residential care activities and social work ac...
# 5258                 Arts, entertainment and recreation
# 5324  Creative, arts and entertainment activities; l...
# 5390  Sports activities and amusement and recreation...
# 5456  Arts, entertainment and recreation; other serv...
# 5522                           Other service activities
# 5588             Activities of membership organisations
# 5654  Repair of computers and personal and household...
# 5720                  Other personal service activities

# %%
# view unique codes
df["Code"].unique()
# Out:
# array(['L', '_T', 'A', 'A01', 'A02', 'A03', 'B', 'BTE', 'C', 'C10T12',
#        'C13T15', 'C16', 'C16T18', 'C17', 'C18', 'C19', 'C20', 'C21',
#        'C22', 'C22_23', 'C23', 'C24', 'C24_25', 'C25', 'C26', 'C27',
#        'C28', 'C29', 'C29_30', 'C30', 'C31T33', 'C31_32', 'C33', 'D', 'E',
#        'E36', 'E37T39', 'F', 'G', 'G45', 'G46', 'G47', 'H', 'H49', 'H50',
#        'H51', 'H52', 'H53', 'I', 'J', 'J58', 'J58T60', 'J59_60', 'J61',
#        'J62_63', 'K', 'K64', 'K65', 'K66', 'M', 'M69T71', 'M69_70', 'M71',
#        'M72', 'M73', 'M73T75', 'M74_75', 'M_N', 'N', 'N77', 'N78', 'N79',
#        'N80T82', 'O', 'OTQ', 'P', 'Q', 'Q86', 'Q87_88', 'R', 'R90T92',
#        'R93', 'RTU', 'S', 'S94', 'S95', 'S96'], dtype=object)

# %%
# view combined codes
combinedCodes = [x for x in df["Code"].unique() if "_" in x and x[:1] != "_"]

# %%
# make a dict so we can identify codes that have hacky combined-parents
lookupComboCodes = {}

for cc in combinedCodes:
    
    codes = cc.split("_")
    assert len(codes) == 2, "Combination codes should alway split into two items around '_'."
    
    if len(codes[0]) > 1 and len(codes[1]) > 1:
        codes[1] = codes[0][:1] + codes[1] # get the letter
    
    lookupComboCodes.update({codes[0]:cc, codes[1]:cc})

lookupComboCodes
# Out:
# {'C22': 'C22_23',
#  'C23': 'C22_23',
#  'C24': 'C24_25',
#  'C25': 'C24_25',
#  'C29': 'C29_30',
#  'C30': 'C29_30',
#  'C31': 'C31_32',
#  'C32': 'C31_32',
#  'J59': 'J59_60',
#  'J60': 'J59_60',
#  'J62': 'J62_63',
#  'J63': 'J62_63',
#  'M': 'M_N',
#  'M69': 'M69_70',
#  'M70': 'M69_70',
#  'M74': 'M74_75',
#  'M75': 'M74_75',
#  'N': 'M_N',
#  'Q87': 'Q87_88',
#  'Q88': 'Q87_88'}

# %%
# Top level code
df["ParentCode"][df["Code"] == "_T"] = ""

# Single letter codes with a parent of total
for totalIsParent in [x for x in list(df["Code"].unique()) if len(x) == 1 and x not in lookupComboCodes.keys()]:
    df["ParentCode"][df["Code"] == totalIsParent] = "_T"

# Combination codes with a parent of total
for totalIsParentKey in [x for x in lookupComboCodes if len(x) == 1]:
    df["ParentCode"][df["Code"] == lookupComboCodes[totalIsParentKey]] = "_T"
    
# 2nd tier combo keys. i.e single letter codes with a combined parent node
for secondTier in [x for x in lookupComboCodes if len(x) == 1]:
    df["ParentCode"][df["Code"] == secondTier] = lookupComboCodes[secondTier]
                     
# the remaining combo keys
for remainingCombinedKey in [x for x in lookupComboCodes.keys() if len(lookupComboCodes[x]) > 3]:
    df["ParentCode"][df["Code"] == remainingCombinedKey] = lookupComboCodes[remainingCombinedKey]
    
# all remaining codes with blank parents 
for code in df["Code"][df["ParentCode"] == ""].unique():
    df["ParentCode"][df["Code"] == code] = code[:1] # clip off the first letter
    
# Override BTE to have Total parent as it doesnt follow the pattern, and Industry is unlikely
# to be a child of mining.
df["ParentCode"][df["Code"] == "BTE"] = "_T" 

df.to_csv("hierarchy_bi2200_activity.csv", index=False)

# %%
# Write to cypher

import pandas as pd
import csv

finalDf = pd.read_csv("hierarchy_bi2200_activity.csv", quoting=csv.QUOTE_ALL)

# Write hierarchy to .cypher
with open("hierarchy.cypher", "w") as f:
    
    f.write("CREATE CONSTRAINT ON (n:`_generic_hierarchy_node_business-investment-activity`) ASSERT n.code IS UNIQUE;")
    f.write("\n")

    # Write the rows
    
    # Track whats being created - DONT create the same node twice
    alreadyDone = {}
    for i, row in finalDf.iterrows():
        
            # SKip first row, we've done that explicitly above
            if row["ParentCode"] != "":
                
                # If we've created a node with this code. Error if its not representing the same label. Otherwise skip. 
                if row["Code"] in alreadyDone.keys():
                    if row["Label"] != alreadyDone[row["Code"]]:
                        raise ValueError("The code {c} has labels of both: '{a}' and '{b}'.".format(a=row["Code"],b=row["Label"],c=alreadyDone[row["Code"]]))
                else:
                    # New node. Create it then add to alreadyDone dictionary.
                    f.write("CREATE (node:`_generic_hierarchy_node_business-investment-activity` { code:'%s',label:'%s' });" % (row["Code"], row["Label"]))
                    f.write("\n")
                    alreadyDone.update({row["Code"]:row["Label"]})     
 
    # Write the relationships
    for i, row in finalDf.iterrows():
        
            if row["ParentCode"] != "":
                
                f.write("MATCH (parent:`_generic_hierarchy_node_business-investment-activity`), (child:`_generic_hierarchy_node_business-investment-activity`) where parent.code = \"%s\" and child.code = \"%s\" CREATE (child)-[:hasParent]->(parent);" %  (row["ParentCode"], row["Code"]))
                f.write("\n")
